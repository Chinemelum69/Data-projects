# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\MAC\\Downloads\\Dataset - Project 1.csv")

# %%
data
# Out:
#      FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION  \
# 0        TOMASA       ARMEN   F   5-18-2014   01-07-2016         Analyst
# 1         ANNIE         NaN   F         NaN   01-07-2016       Associate
# 2         OLIVE        ANCY   F   7-28-2014   01-07-2016         Analyst
# 3        CHERRY     AQUILAR   F  04-03-2013   01-07-2016         Analyst
# 4          LEON  ABOULAHOUD   M  11-20-2014   01-07-2016         Analyst
# ...         ...         ...  ..         ...          ...             ...
# 2634  KATHERINE      ALSDON   F   6-28-2011   01-07-2016  Senior Manager
# 2635     LOUISE     ALTARAS   F   1-14-2014   01-07-2016         Analyst
# 2636      RENEE      ALVINO   F   1-23-2014   01-07-2016         Analyst
# 2637       TERI   ANASTASIO   F   3-17-2014   01-07-2016         Analyst
# 2638    GREGORY      ABARCA   M   9-18-2014   01-07-2016         Analyst
#
#        AGE  SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  \
# ...

# %%
#understanding the dataset

# %%
data.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# 0   44570     Finance         24.0               6.0      2.0         0
# 1   89207         Web          NaN              13.0      NaN         7
# 2   40955     Finance         23.0               7.0      3.0         0
# 3   45550          IT         22.0               8.0      3.0         0
# 4   43161  Operations         27.0               3.0      NaN         3

# %%
data.tail()
# Out:
#      FIRST NAME  LAST NAME SEX        DOJ CURRENT DATE     DESIGNATION   AGE  \
# 2634  KATHERINE     ALSDON   F  6-28-2011   01-07-2016  Senior Manager  36.0
# 2635     LOUISE    ALTARAS   F  1-14-2014   01-07-2016         Analyst  23.0
# 2636      RENEE     ALVINO   F  1-23-2014   01-07-2016         Analyst  21.0
# 2637       TERI  ANASTASIO   F  3-17-2014   01-07-2016         Analyst  24.0
# 2638    GREGORY     ABARCA   M  9-18-2014   01-07-2016         Analyst  24.0
#
#       SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# 2634  185977  Management         15.0              15.0      5.0        10
# 2635   45758          IT         17.0              13.0      2.0         0
# 2636   47315         Web         29.0               1.0      5.0         0
# 2637   45172         Web         23.0               7.0      3.0         1
# 2638   49176   Marketing         17.0              13.0      2.0         2

# %%
data.describe()
# Out:
#                AGE         SALARY  LEAVES USED  LEAVES REMAINING      RATINGS  \
# count  2636.000000    2639.000000  2636.000000       2637.000000  2637.000000
# mean     24.756449   58136.678287    22.501517          7.503223     3.486159
# std       3.908228   36876.956944     4.604469          4.603193     1.114933
# min      21.000000   40001.000000    15.000000          0.000000     2.000000
# 25%      22.000000   43418.000000    19.000000          4.000000     2.000000
# 50%      24.000000   46781.000000    22.000000          8.000000     3.000000
# 75%      25.000000   51401.500000    26.000000         11.000000     4.000000
# max      45.000000  388112.000000    30.000000         15.000000     5.000000
#
#           PAST EXP
# count  2639.000000
# mean      1.566881
# std       2.728416
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max      23.000000

# %%
data.nunique()
# Out:
# FIRST NAME          2367
# LAST NAME           2475
# SEX                    2
# DOJ                  967
# CURRENT DATE           1
# DESIGNATION            6
# AGE                   25
# SALARY              2305
# UNIT                   6
# LEAVES USED           16
# LEAVES REMAINING      16
# RATINGS                4
# PAST EXP              21
# dtype: int64

# %%
#cleaning the data

# %%
data.isnull().sum()
# Out:
# FIRST NAME          0
# LAST NAME           2
# SEX                 0
# DOJ                 1
# CURRENT DATE        0
# DESIGNATION         0
# AGE                 3
# SALARY              0
# UNIT                0
# LEAVES USED         3
# LEAVES REMAINING    2
# RATINGS             2
# PAST EXP            0
# dtype: int64

# %%
#printing all null record

# %%
a = data.isnull().any(axis=1)
b = data[a]
print(b)
# Out:
#    FIRST NAME    LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION   AGE  \
# 1       ANNIE          NaN   F         NaN   01-07-2016       Associate   NaN
# 4        LEON   ABOULAHOUD   M  11-20-2014   01-07-2016         Analyst   NaN
# 5    VICTORIA          NaN   F   2-19-2013   01-07-2016         Analyst  22.0
# 7     JACQUES        AKMAL   M  12-05-2013   01-07-2016         Analyst   NaN
# 11     VIRGIL       ACKIES   M  02-01-2010   01-07-2016  Senior Manager  36.0
# 15    CORINNE  ANDRZEJCZYK   F   8-13-2014   01-07-2016         Analyst  21.0
# 19    PHILLIP       ABDULA   M  07-03-2013   01-07-2016         Analyst  24.0
# 23      WENDI       APPERT   F  12-02-2013   01-07-2016         Analyst  25.0
#
#     SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# 1    89207         Web          NaN              13.0      NaN         7
# 4    43161  Operations         27.0               3.0      NaN         3
# ...

# %%
#deleting redundant and irrelevant values

# %%
salary = data.drop(['LEAVES USED','LEAVES REMAINING','CURRENT DATE'],axis=1)

# %%
salary.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ DESIGNATION   AGE  SALARY  \
# 0     TOMASA       ARMEN   F   5-18-2014     Analyst  21.0   44570
# 1      ANNIE         NaN   F         NaN   Associate   NaN   89207
# 2      OLIVE        ANCY   F   7-28-2014     Analyst  21.0   40955
# 3     CHERRY     AQUILAR   F  04-03-2013     Analyst  22.0   45550
# 4       LEON  ABOULAHOUD   M  11-20-2014     Analyst   NaN   43161
#
#          UNIT  RATINGS  PAST EXP
# 0     Finance      2.0         0
# 1         Web      NaN         7
# 2     Finance      3.0         0
# 3          IT      3.0         0
# 4  Operations      NaN         3

# %%
#relationship analysis

# %%
sns.distplot(salary['AGE'],bins =5)
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_6236\236151013.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(salary['AGE'],bins =5)
# <Axes: xlabel='AGE', ylabel='Density'>

# %%
sns.catplot(x='PAST EXP',kind = 'box',data= salary)
# Out:
# C:\Users\MAC\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#feature engineering

# %%
data.head(30)
# Out:
#    FIRST NAME    LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION   AGE  \
# 0      TOMASA        ARMEN   F   5-18-2014   01-07-2016         Analyst  21.0
# 1       ANNIE          NaN   F         NaN   01-07-2016       Associate   NaN
# 2       OLIVE         ANCY   F   7-28-2014   01-07-2016         Analyst  21.0
# 3      CHERRY      AQUILAR   F  04-03-2013   01-07-2016         Analyst  22.0
# 4        LEON   ABOULAHOUD   M  11-20-2014   01-07-2016         Analyst   NaN
# 5    VICTORIA          NaN   F   2-19-2013   01-07-2016         Analyst  22.0
# 6      ELLIOT       AGULAR   M  09-02-2013   01-07-2016         Analyst  22.0
# 7     JACQUES        AKMAL   M  12-05-2013   01-07-2016         Analyst   NaN
# 8       KATHY        ALSOP   F   6-29-2014   01-07-2016  Senior Analyst  28.0
# 9      LILIAN        APELA   F  11-11-2014   01-07-2016         Analyst  22.0
# 10      BELLE         ARDS   F  03-10-2014   01-07-2016         Analyst  24.0
# ...

# %%
da
